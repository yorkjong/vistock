# %% [markdown]
# <a href="https://colab.research.google.com/github/yorkjong/vistock/blob/main/notebooks/bull_draw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### This notebook shows stock charts to demonstrate BullRun and Drawdown.

# %% [markdown]
# ### Install Required Packages

# %%
# %pip install git+https://github.com/yorkjong/vistock.git
# Out:
# Collecting git+https://github.com/yorkjong/vistock.git
#   Cloning https://github.com/yorkjong/vistock.git to /tmp/pip-req-build-5wq9vkam
#   Running command git clone --filter=blob:none --quiet https://github.com/yorkjong/vistock.git /tmp/pip-req-build-5wq9vkam
#   Resolved https://github.com/yorkjong/vistock.git to commit d17da5fe0e41aaaa20f5d0d0cb2019027263ec74
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.3) (2.1.4)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.3) (0.2.41)
# Collecting mplfinance (from vistock==0.3.3)
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.3) (5.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.3) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.3) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->vistock==0.3.3) (2.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance->vistock==0.3.3) (3.7.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.3.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.3.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.3.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.3.3) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->vistock==0.3.3) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly->vistock==0.3.3) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.3.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.3.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.3.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.3.3) (2024.7.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.3) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.3) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.3) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.3) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.3) (3.17.6)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.3) (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance->vistock==0.3.3) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance->vistock==0.3.3) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.3) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.3) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.3) (3.1.2)
# Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.9 MB/s eta 0:00:00
# Building wheels for collected packages: vistock
#   Building wheel for vistock (setup.py) ... done
#   Created wheel for vistock: filename=vistock-0.3.3-py3-none-any.whl size=34343 sha256=be3e2cc4925a77109bdeb988403815fc40335c3d68f40b345c2106bce2646781
#   Stored in directory: /tmp/pip-ephem-wheel-cache-es63s34s/wheels/1f/ff/6c/9ec0adab3f1af71ff9ba3e4eb52d0f3849d3a695b812dc509a
# Successfully built vistock
# Installing collected packages: mplfinance, vistock
# Successfully installed mplfinance-0.12.10b0 vistock-0.3.3

# %% [markdown]
# ### Usage Explanation

# %% [markdown]
# #### Parameters
#
# symbol (股票代碼):
# * The symbol of a stock (e.g., TSLA)
# * This also suport some to crypto to USD pairs (e.g., BTC-USD, ETH-USD)
#
# period (整張圖的繪製區間):
# * the period of data to download
#
# interval (每筆k線資料的間隔):
# * the interval of an OHLC data item
#
# legend_location（圖例說明匡的位置; for mplfinance version）:
# * the loacation of the legend
#
# hides_nontrading（是否隱藏非交易的期間; for Plotly version）
# * decide if hides non-trading time-periods.
#
#
# #### Colab Forms
# * Forms provide an easy way to parameterize code.
# * Forms are Google Colab specific features extending from the original Jupyter Notebooks.
# * After running a cell manually, it will auto-run if you change the selected value.

# %% [markdown]
# ### Plot with mplfinance

# %%
# @title  { run: "auto", display-mode: "form" }
symbol = "TSLA" #@param ["TSLA", "NVDA", "MSFT", "AAPL", "GOOG", "MSTR", "TQQQ", "SOXL", "TSM", "台積電", "2330", "元太", "BTC-USD", "ETH-USD"] {allow-input: true}
period = "2y" #@param ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
interval = '1wk' #@param ['1m', '2m', '5m', '15m', '30m', '60m', '90m', '1h', '1d', '5d', '1wk', '1mo', '3mo']
legend_location = "best" #@param ["best", "upper right", "upper left", 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center']
style = "binancedark" # @param ["yahoo","charles","tradingview","binance","binancedark","mike","nightclouds","checkers","ibd","sas","starsandstripes","kenan","blueskies","brasil"]
hides_nontrading = True # @param {"type":"boolean"}

from vistock.mpl import bull_draw

bull_draw.plot(symbol, period=period, interval=interval,
               legend_loc=legend_location,
               style=style, hides_nontrading=hides_nontrading)

# %% [markdown]
# ### Plot with Plotly

# %%
# @title  { run: "auto", display-mode: "form" }
symbol = "TSLA" #@param ["TSLA", "NVDA", "MSFT", "AAPL", "GOOG", "MSTR", "TQQQ", "SOXL", "TSM", "台積電", "2330", "元太", "BTC-USD", "ETH-USD"] {allow-input: true}
period = "5y" #@param ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
interval = '1wk' #@param ['1m', '2m', '5m', '15m', '30m', '60m', '90m', '1h', '1d', '5d', '1wk', '1mo', '3mo']
hides_nontrading = True #@param {type:"boolean"}

from vistock.plotly import bull_draw


bull_draw.plot(symbol, period=period, interval=interval,
               hides_nontrading=hides_nontrading)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dec540f7-40e1-4c1e-8431-7c3661105428" class="plotly-graph-div" style="height:720px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dec540f7-40e1-4c1e-8431-7c3661105428")) {                    Plotly.newPlot(                        "dec540f7-40e1-4c1e-8431-7c3661105428",                        [{"line":{"color":"brown","width":2},"name":"Price","x":["2019-08-12T00:00:00-04:00","2019-08-19T00:00:00-04:00","2019-08-26T00:00:00-04:00","2019-09-02T00:00:00-04:00","2019-09-09T00:00:00-04:00","2019-09-16T00:00:00-04:00","2019-09-23T00:00:00-04:00","2019-09-30T00:00:00-04:00","2019-10-07T00:00:00-04:00","2019-10-14T00:00:00-04:00","2019-10-21T00:00:00-04:00","2019-10-28T00:00:00-04:00","2019-11-04T00:00:00-05:00","2019-11-11T00:00:00-05:00","2019-11-18T00:00:00-05:00","2019-11-25T00:00:00-05:00","2019-12-02T00:00:00-05:00","2019-12-09T00:00:00-05:00","2019-12-16T00:00:00-05:00","2019-12-23T00:00:00-05:00","2019-12-30T00:00:00-05:00","2020-01-06T00:00:00-05:00","2020-01-13T00:00:00-05:00","2020-01-20T00:00:00-05:00","2020-01-27T00:00:00-05:00","2020-02-03T00:00:00-05:00","2020-02-10T00:00:00-05:00","2020-02-17T00:00:00-05:00","2020-02-24T00:00:00-05:00","2020-03-02T00:00:00-05:00","2020-03-09T00:00:00-04:00","2020-03-16T00:00:00-04:00","2020-03-23T00:00:00-04:00","2020-03-30T00:00:00-04:00","2020-04-06T00:00:00-04:00","2020-