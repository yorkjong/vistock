# %% [markdown]
# <a href="https://colab.research.google.com/github/YorkJong/vistock/blob/main/notebooks/bull_draw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### This notebook shows stock charts to demonstrate BullRun and Drawdown.

# %% [markdown]
# ### Install vistock from GitHub (免費版Colab會固定時間清掉安裝的東西，所以重安裝是新連線後最先要做的事)

# %%
# %pip install git+https://github.com/YorkJong/vistock.git#0.3.1
# Out:
# Collecting git+https://github.com/YorkJong/vistock.git#0.3.1
#   Cloning https://github.com/YorkJong/vistock.git to /tmp/pip-req-build-kzdkefv8
#   Running command git clone --filter=blob:none --quiet https://github.com/YorkJong/vistock.git /tmp/pip-req-build-kzdkefv8
#   Resolved https://github.com/YorkJong/vistock.git to commit 08f7da71411b28b937ece6a4a9476b1d183843f5
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.1) (2.0.3)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.1) (0.2.40)
# Requirement already satisfied: mplfinance in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.1) (0.12.10b0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.1) (5.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.1) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from vistock==0.3.1) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->vistock==0.3.1) (2.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance->vistock==0.3.1) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.3.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.3.1) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.3.1) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.3.1) (1.25.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->vistock==0.3.1) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly->vistock==0.3.1) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.3.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.3.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.3.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.3.1) (2024.7.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.1) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.1) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.1) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.1) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.1) (3.17.6)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.3.1) (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance->vistock==0.3.1) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance->vistock==0.3.1) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.3.1) (3.1.2)

# %% [markdown]
# ### Usage Explanation

# %% [markdown]
# #### Parameters
#
# symbol (股票代碼):
# * The symbol of a stock (e.g., TSLA)
# * This also suport some to crypto to USD pairs (e.g., BTC-USD, ETH-USD)
#
# period (整張圖的繪製區間):
# * the period of data to download
#
# interval (每筆k線資料的間隔):
# * the interval of an OHLC data item
#
# legend_location （圖例說明匡的位置）:
# * the loacation of the legend
#
# #### Colab Forms
# * Forms provide an easy way to parameterize code.
# * Forms are Google Colab specific features extending from the original Jupyter Notebooks.
# * After running a cell manually, it will auto-run if you change the selected value.

# %% [markdown]
# ### Plot with mplfinance

# %%
# @title  { run: "auto", display-mode: "form" }
symbol = "NVDA" #@param ["TSLA", "NVDA", "MSFT", "AAPL", "GOOG", "MSTR", "TQQQ", "SOXL", "TSM", "台積電", "2330", "元太", "BTC-USD", "ETH-USD"] {allow-input: true}
period = "1y" #@param ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
interval = '1d' #@param ['1m', '2m', '5m', '15m', '30m', '60m', '90m', '1h', '1d', '5d', '1wk', '1mo', '3mo']
legend_location = "best" #@param ["best", "upper right", "upper left", 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center']

from vistock.mpl import bull_draw

bull_draw.plot(symbol, period=period, interval=interval,
               legend_loc=legend_location)

# %% [markdown]
# ### Plot with Plotly

# %%
# @title  { run: "auto", display-mode: "form" }
symbol = "TSLA" #@param ["TSLA", "NVDA", "MSFT", "AAPL", "GOOG", "MSTR", "TQQQ", "SOXL", "TSM", "台積電", "2330", "元太", "BTC-USD", "ETH-USD"] {allow-input: true}
period = "1y" #@param ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
interval = '1d' #@param ['1m', '2m', '5m', '15m', '30m', '60m', '90m', '1h', '1d', '5d', '1wk', '1mo', '3mo']
hides_nontrading = True #@param {type:"boolean"}

from vistock.plotly import bull_draw


bull_draw.plot(symbol, period=period, interval=interval,
               hides_nontrading=hides_nontrading)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b274d59c-75c1-41af-8389-7bf04dd500b2" class="plotly-graph-div" style="height:720px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b274d59c-75c1-41af-8389-7bf04dd500b2")) {                    Plotly.newPlot(                        "b274d59c-75c1-41af-8389-7bf04dd500b2",                        [{"line":{"color":"brown","width":2},"name":"Price","x":["2023-07-20T00:00:00-04:00","2023-07-21T00:00:00-04:00","2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00 ...
